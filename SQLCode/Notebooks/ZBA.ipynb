-- %% [markdown]
-- # **ALTER DDASWEEPS TABLE ON BANKLINEFSB**

-- %%
USE BanklineFSB
GO
ALTER TABLE dbo.DDASWEEPS DROP COLUMN [INV_APP_CODE],
               [INV_ACCOUNT],
               [LOAN_ACCOUNT],
               [AMT_TO_KEEP_AT_PARENT1],
               [AMT_TO_KEEP_AT_PARENT],
               [INV_LIMIT_MIN],
               [INV_LIMIT_MAX],
               [INV_LIMIT_INCR]
GO

USE BanklineWNB
GO
ALTER TABLE dbo.DDASWEEPS DROP COLUMN [INV_APP_CODE],
               [INV_ACCOUNT],
               [LOAN_ACCOUNT],
               [AMT_TO_KEEP_AT_PARENT1],
               [AMT_TO_KEEP_AT_PARENT],
               [INV_LIMIT_MIN],
               [INV_LIMIT_MAX],
               [INV_LIMIT_INCR]
GO

-- %%
USE [BanklineFSB]
GO
IF OBJECT_ID('dbo.DDASWEEPS','U') IS NOT NULL
BEGIN
    ALTER TABLE dbo.DDASWEEPS ADD
    [AVAIL_BALS]                money       NULL,
    [AVAIL_NET]                 money       NULL, 
    [INV_APP_CODE]              VARCHAR(3)  NULL,
    [INV_ACCOUNT]               VARCHAR(13) NULL,
    [LOAN_ACCOUNT]              VARCHAR(13) NULL,
    [AMT_TO_KEEP_AT_PARENT1]    money       NULL,
    [AMT_TO_KEEP_AT_PARENT]     money       NULL,
    [INV_LIMIT_MIN]             money       NULL,
    [INV_LIMIT_MAX]             money       NULL,
    [INV_LIMIT_INCR]            money       NULL
END
GO

-- %% [markdown]
-- # **ALTER DDASWEEPS TABLE ON BANKLINEWNB**

-- %%
USE [BanklineWNB]
GO
IF OBJECT_ID('dbo.DDASWEEPS','U') IS NOT NULL
BEGIN
    ALTER TABLE dbo.DDASWEEPS ADD 
    [AVAIL_BALS]                money       NULL,
    [AVAIL_NET]                 money       NULL, 
    [INV_APP_CODE]              VARCHAR(3)  NULL,
    [INV_ACCOUNT]               VARCHAR(13) NULL,
    [LOAN_ACCOUNT]              VARCHAR(13) NULL,
    [AMT_TO_KEEP_AT_PARENT1]    money       NULL,
    [AMT_TO_KEEP_AT_PARENT]     money       NULL,
    [INV_LIMIT_MIN]             money       NULL,
    [INV_LIMIT_MAX]             money       NULL,
    [INV_LIMIT_INCR]            money       NULL
END
GO

-- %% [markdown]
-- # **RECREATING VIEW BANKLINE.dbo.DDASWEEPS**

-- %%
USE [Bankline]
GO

DROP VIEW IF EXISTS [dbo].[DDASWEEPS]
GO

SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE VIEW [dbo].[DDASWEEPS]
AS
               SELECT 1 as InstitutionID,
               [Z_ID],
               [AVAIL_BAL],
               [DEBITS],
               [CREDITS],
               [ENDING_BAL],
               [ACCT_TYP],
               [ACCT_NO],
               [MIN_BAL],
               [MAX_BAL],
               [MIN_INCREMENT],
               [AVAIL_BALS],
               [AVAIL_NET],
               [INV_APP_CODE],
               [INV_ACCOUNT],
               [LOAN_ACCOUNT],
               [AMT_TO_KEEP_AT_PARENT1],
               [AMT_TO_KEEP_AT_PARENT],
               [INV_LIMIT_MIN],
               [INV_LIMIT_MAX],
               [INV_LIMIT_INCR]
          FROM
               [BanklineWNB].[dbo].[DDASWEEPS]
     UNION
          SELECT 2 as InstitutionID,
               [Z_ID],
               [AVAIL_BAL],
               [DEBITS],
               [CREDITS],
               [ENDING_BAL],
               [ACCT_TYP],
               [ACCT_NO],
               [MIN_BAL],
               [MAX_BAL],
               [MIN_INCREMENT],
               [AVAIL_BALS],
               [AVAIL_NET],
               [INV_APP_CODE],
               [INV_ACCOUNT],
               [LOAN_ACCOUNT],
               [AMT_TO_KEEP_AT_PARENT1],
               [AMT_TO_KEEP_AT_PARENT],
               [INV_LIMIT_MIN],
               [INV_LIMIT_MAX],
               [INV_LIMIT_INCR]
          FROM
               [BanklineFSB].[dbo].[DDASWEEPS]
GO

-- %% [markdown]
-- # **ALTERING DDACONTROL1 TABLE ON BANKILEFSB**

-- %%
USE [BanklineFSB]
GO
IF OBJECT_ID('dbo.DDACONTROL1','U') IS NOT NULL
BEGIN
    ALTER TABLE dbo.DDACONTROL1 ADD 
    [THIRD_PTY_DB_CNT]    CHAR(1)  NULL
END
GO

-- %%
USE [BanklineWNB]
GO
IF OBJECT_ID('dbo.DDACONTROL1','U') IS NOT NULL
BEGIN
    ALTER TABLE dbo.DDACONTROL1 ADD 
    [THIRD_PTY_DB_CNT]    CHAR(1)  NULL
END
GO

-- %%
USE [Bankline]
GO

DROP VIEW IF EXISTS [dbo].[DDACONTROL1]
GO
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO

CREATE VIEW [dbo].[DDACONTROL1]
AS
SELECT 1 as InstitutionID,
     [Z_ID],
     [SHORT_NAME],
     [BRCH],
     [SOC_SEC],
     [DATE_OPN],
     [COLL_BAL],
     [OFFICER],
     [NUM_UNPOST],
     [CHKS_NSF_LIFE],
     [CRR_LOAN_BAL],
     [ACCT_ANLYS],
     [ITMS_NSF_YTD],
     [ACCT],
     [CK_PAY_STAT],
     [CK_PAY_OD_AMT],
     [REASON_TO_WATCH],
     [CRR_LIMIT],
     [CHGBCK_LTD],
     [DebitCardOptIn],
     [LST_DEP_DT],
     [LST_DEP_AMT],
     [OD_LIMIT],
     [YTD_INT_PD],
     [PYR_INT_PD],
     [DYS_OD_SINCE_POS],
     [CHGBCK_YTD],
     [CHGBCK_MTD],
     [PrivPayODOptIn],
     [ODDebitCardEffective],
	 [OD_OPT_IN],
     [OD_OPT_IN_DATE_CHANGE],
     [THIRD_PTY_DB_CNT]
FROM
     [BanklineWNB].[dbo].[DDACONTROL1]
UNION
SELECT 2 as InstitutionID,
     [Z_ID],
     [SHORT_NAME],
     [BRCH],
     [SOC_SEC],
     [DATE_OPN],
     [COLL_BAL],
     [OFFICER],
     [NUM_UNPOST],
     [CHKS_NSF_LIFE],
     [CRR_LOAN_BAL],
     [ACCT_ANLYS],
     [ITMS_NSF_YTD],
     [ACCT],
     [CK_PAY_STAT],
     [CK_PAY_OD_AMT],
     [REASON_TO_WATCH],
     [CRR_LIMIT],
     [CHGBCK_LTD],
     [DebitCardOptIn],
     [LST_DEP_DT],
     [LST_DEP_AMT],
     [OD_LIMIT],
     [YTD_INT_PD],
     [PYR_INT_PD],
     [DYS_OD_SINCE_POS],
     [CHGBCK_YTD],
     [CHGBCK_MTD],
     [PrivPayODOptIn],
     [ODDebitCardEffective],
	 [OD_OPT_IN],
     [OD_OPT_IN_DATE_CHANGE],
     [THIRD_PTY_DB_CNT]
FROM
     [BanklineFSB].[dbo].[DDACONTROL1]
GO

-- %% [markdown]
-- # **ALTERING DDACLASS TABLE**

-- %%
USE [BanklineFSB]
GO

IF OBJECT_ID('dbo.DDACLASS','U') IS NOT NULL
BEGIN
    ALTER TABLE dbo.DDACLASS ADD 
    [DP_MIN_OPEN]           money       NULL,
    [INT_RATE]              money       NULL,
    [INT_TYPE]              varchar(3)  NULL,
    [HI_BAL]                money       NULL,
    [HI_DEPOSIT]            money       NULL,
    [YTD_MAX_DEP]           money       NULL,
    [HI_CHK_DEP]            money       NULL,
    [HI_DEP_CNT]            money       NULL,
    [HI_CHEX_CNT]           money       NULL,
    [1099_REQ]              char(1)     NULL,
    [OWNER_DOB]             char(1)     NULL,
    [SIG_BAL_CHG]           money       NULL,
    [FDIC_ASSMNT]           char(1)     NULL,
    [STT_SVC_CHG]           int         NULL,
    [STT_PR_AVG]            char(1)     NULL,
    [STT_PR_AVGC]           char(1)     NULL,
    [STT_PR_MIN]            char(1)     NULL,
    [DP_VAR_FLAG]           char(1)     NULL,
    [ZIP_SORT]              char(1)     NULL,
    [SAVINGS]               char(1)     NULL,
    [MM_ACCOUNT]            char(1)     NULL,
    [ANNUAL_SC]             char(1)     NULL,
    [DFLT_OD_LIM]           int         NULL,
    [REVOKE_ODDY]           int         NULL,
    [REVOKE_ODS]            int         NULL,
    [STT_PRT_RT]            int         NULL,
    [TAXABLE]               int         NULL,
    [DFLT_SVC_CD]           varchar(10) NULL,
    [DFLT_FED_CT]           varchar(5)  NULL,
    [DFLT_IMG_ST]           char(1)     NULL,
    [DFLT_NIMGWV]           char(1)     NULL,
    [ADJ_SVC_OD]            char(1)     NULL,
    [AFTER_W1]              int         NULL,
    [PSTV_PAY_OK]           int         NULL,
    [DEF_MAX_FEE]           money       NULL,
    [HSA]                   char(1)     NULL,
    [NOW]                   char(1)     NULL,
    [CALLR]                 varchar(3)  NULL,
    [MKT_DESCRP1]           varchar(40) NULL,
    [MKT_DESCRP2]           varchar(40) NULL,
    [MKT_DESCRP3]           varchar(40) NULL,
    [IB_DISPLAY]            varchar(3)  NULL,
    [IB_XFER_FRM]           varchar(3)  NULL,
    [IB_XFER_TO]            varchar(3)  NULL,
    [VR_DISPLAY]            varchar(3)  NULL,
    [VR_XFER_FRM]           varchar(3)  NULL,
    [VR_XFER_TO]            varchar(3)  NULL,
    [BYPASS_RC_O]           varchar(3)  NULL,
    [DEF_PC_BNKG]           varchar(3)  NULL,
    [DEF_INTBLPY]           varchar(3)  NULL,
    [DEF_EVNTMSG]           varchar(3)  NULL,
    [DEF_ENOTICS]           varchar(3)  NULL,
    [SETUP_FEE]             smallint    NULL,
    [CLS_CHG_FEE]           smallint    NULL,
    [WV_C_OD_FEE]           smallint    NULL,
    [TIERED_FEE]            money       NULL,
    [DISPLAY_PRI]           varchar(3)  NULL,
    [DISPLAY_Y_N]           char(1)     NULL,
    [AFTER_W1_AA]           char(3)     NULL,
    [DFLT_WV_NSF]           char(3)     NULL,
    [DFLT_WV_OD]            char(3)     NULL,
    [DFLT_WV_COD]           char(3)     NULL,
    [DFLT_PY_ALL]           char(3)     NULL,
    [DFLT_WV_CBK]           char(3)     NULL,
    [DFLT_CYCLE]            char(3)     NULL,
    [INTRNL_ACCT]           char(3)     NULL
END

-- %%
USE [BanklineWNB]
GO

IF OBJECT_ID('dbo.DDACLASS','U') IS NOT NULL
BEGIN
    ALTER TABLE dbo.DDACLASS ADD 
    [DP_MIN_OPEN]           money       NULL,
    [INT_RATE]              money       NULL,
    [INT_TYPE]              varchar(3)  NULL,
    [HI_BAL]                money       NULL,
    [HI_DEPOSIT]            money       NULL,
    [YTD_MAX_DEP]           money       NULL,
    [HI_CHK_DEP]            money       NULL,
    [HI_DEP_CNT]            money       NULL,
    [HI_CHEX_CNT]           money       NULL,
    [1099_REQ]              char(1)     NULL,
    [OWNER_DOB]             char(1)     NULL,
    [SIG_BAL_CHG]           money       NULL,
    [FDIC_ASSMNT]           char(1)     NULL,
    [STT_SVC_CHG]           int         NULL,
    [STT_PR_AVG]            char(1)     NULL,
    [STT_PR_AVGC]           char(1)     NULL,
    [STT_PR_MIN]            char(1)     NULL,
    [DP_VAR_FLAG]           char(1)     NULL,
    [ZIP_SORT]              char(1)     NULL,
    [SAVINGS]               char(1)     NULL,
    [MM_ACCOUNT]            char(1)     NULL,
    [ANNUAL_SC]             char(1)     NULL,
    [DFLT_OD_LIM]           int         NULL,
    [REVOKE_ODDY]           int         NULL,
    [REVOKE_ODS]            int         NULL,
    [STT_PRT_RT]            int         NULL,
    [TAXABLE]               int         NULL,
    [DFLT_SVC_CD]           varchar(10) NULL,
    [DFLT_FED_CT]           varchar(5)  NULL,
    [DFLT_IMG_ST]           char(1)     NULL,
    [DFLT_NIMGWV]           char(1)     NULL,
    [ADJ_SVC_OD]            char(1)     NULL,
    [AFTER_W1]              int         NULL,
    [PSTV_PAY_OK]           int         NULL,
    [DEF_MAX_FEE]           money       NULL,
    [HSA]                   char(1)     NULL,
    [NOW]                   char(1)     NULL,
    [CALLR]                 varchar(3)  NULL,
    [MKT_DESCRP1]           varchar(40) NULL,
    [MKT_DESCRP2]           varchar(40) NULL,
    [MKT_DESCRP3]           varchar(40) NULL,
    [IB_DISPLAY]            varchar(3)  NULL,
    [IB_XFER_FRM]           varchar(3)  NULL,
    [IB_XFER_TO]            varchar(3)  NULL,
    [VR_DISPLAY]            varchar(3)  NULL,
    [VR_XFER_FRM]           varchar(3)  NULL,
    [VR_XFER_TO]            varchar(3)  NULL,
    [BYPASS_RC_O]           varchar(3)  NULL,
    [DEF_PC_BNKG]           varchar(3)  NULL,
    [DEF_INTBLPY]           varchar(3)  NULL,
    [DEF_EVNTMSG]           varchar(3)  NULL,
    [DEF_ENOTICS]           varchar(3)  NULL,
    [SETUP_FEE]             smallint    NULL,
    [CLS_CHG_FEE]           smallint    NULL,
    [WV_C_OD_FEE]           smallint    NULL,
    [TIERED_FEE]            money       NULL,
    [DISPLAY_PRI]           varchar(3)  NULL,
    [DISPLAY_Y_N]           char(1)     NULL,
    [AFTER_W1_AA]           char(3)     NULL,
    [DFLT_WV_NSF]           char(3)     NULL,
    [DFLT_WV_OD]            char(3)     NULL,
    [DFLT_WV_COD]           char(3)     NULL,
    [DFLT_PY_ALL]           char(3)     NULL,
    [DFLT_WV_CBK]           char(3)     NULL,
    [DFLT_CYCLE]            char(3)     NULL,
    [INTRNL_ACCT]           char(3)     NULL
END

-- %% [markdown]
-- # **RECREATING DDACLASS VIEW ON BANKLINE DATABASE**

-- %%
USE [Bankline]
GO

DROP VIEW IF EXISTS [dbo].[DDACLASS]
GO
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE VIEW [dbo].[DDACLASS]
AS
            SELECT 1 as InstitutionID,
            [class],
            [class_desc],
            [Acct_type],
            [DP_MIN_OPEN],
            [INT_RATE],
            [INT_TYPE],
            [HI_BAL],
            [HI_DEPOSIT],
            [YTD_MAX_DEP],
            [HI_CHK_DEP],
            [HI_DEP_CNT],
            [HI_CHEX_CNT],
            [1099_REQ],
            [OWNER_DOB],
            [SIG_BAL_CHG],
            [FDIC_ASSMNT],
            [STT_SVC_CHG],
            [STT_PR_AVG],
            [STT_PR_AVGC],
            [STT_PR_MIN],
            [DP_VAR_FLAG],
            [ZIP_SORT],
            [SAVINGS],
            [MM_ACCOUNT],
            [ANNUAL_SC],
            [DFLT_OD_LIM],
            [REVOKE_ODDY],
            [REVOKE_ODS],
            [STT_PRT_RT],
            [TAXABLE],
            [DFLT_SVC_CD],
            [DFLT_FED_CT],
            [DFLT_IMG_ST],
            [DFLT_NIMGWV],
            [ADJ_SVC_OD],
            [AFTER_W1],
            [PSTV_PAY_OK],
            [DEF_MAX_FEE],
            [HSA],
            [NOW],
            [CALLR],
            [MKT_DESCRP1],
            [MKT_DESCRP2],
            [MKT_DESCRP3],
            [IB_DISPLAY],
            [IB_XFER_FRM],
            [IB_XFER_TO],
            [VR_DISPLAY],
            [VR_XFER_FRM],
            [VR_XFER_TO],
            [BYPASS_RC_O],
            [DEF_PC_BNKG],
            [DEF_INTBLPY],
            [DEF_EVNTMSG],
            [DEF_ENOTICS],
            [SETUP_FEE],
            [CLS_CHG_FEE],
            [WV_C_OD_FEE],
            [TIERED_FEE],
            [DISPLAY_PRI],
            [DISPLAY_Y_N],
            [AFTER_W1_AA],
            [DFLT_WV_NSF],
            [DFLT_WV_OD],
            [DFLT_WV_COD],
            [DFLT_PY_ALL],
            [DFLT_WV_CBK],
            [DFLT_CYCLE],
            [INTRNL_ACCT]
        FROM
            [BanklineWNB].[dbo].[DDACLASS]
    UNION
        SELECT 2 as InstitutionID,
            [class],
            [class_desc],
            [Acct_type],
            [DP_MIN_OPEN],
            [INT_RATE],
            [INT_TYPE],
            [HI_BAL],
            [HI_DEPOSIT],
            [YTD_MAX_DEP],
            [HI_CHK_DEP],
            [HI_DEP_CNT],
            [HI_CHEX_CNT],
            [1099_REQ],
            [OWNER_DOB],
            [SIG_BAL_CHG],
            [FDIC_ASSMNT],
            [STT_SVC_CHG],
            [STT_PR_AVG],
            [STT_PR_AVGC],
            [STT_PR_MIN],
            [DP_VAR_FLAG],
            [ZIP_SORT],
            [SAVINGS],
            [MM_ACCOUNT],
            [ANNUAL_SC],
            [DFLT_OD_LIM],
            [REVOKE_ODDY],
            [REVOKE_ODS],
            [STT_PRT_RT],
            [TAXABLE],
            [DFLT_SVC_CD],
            [DFLT_FED_CT],
            [DFLT_IMG_ST],
            [DFLT_NIMGWV],
            [ADJ_SVC_OD],
            [AFTER_W1],
            [PSTV_PAY_OK],
            [DEF_MAX_FEE],
            [HSA],
            [NOW],
            [CALLR],
            [MKT_DESCRP1],
            [MKT_DESCRP2],
            [MKT_DESCRP3],
            [IB_DISPLAY],
            [IB_XFER_FRM],
            [IB_XFER_TO],
            [VR_DISPLAY],
            [VR_XFER_FRM],
            [VR_XFER_TO],
            [BYPASS_RC_O],
            [DEF_PC_BNKG],
            [DEF_INTBLPY],
            [DEF_EVNTMSG],
            [DEF_ENOTICS],
            [SETUP_FEE],
            [CLS_CHG_FEE],
            [WV_C_OD_FEE],
            [TIERED_FEE],
            [DISPLAY_PRI],
            [DISPLAY_Y_N],
            [AFTER_W1_AA],
            [DFLT_WV_NSF],
            [DFLT_WV_OD],
            [DFLT_WV_COD],
            [DFLT_PY_ALL],
            [DFLT_WV_CBK],
            [DFLT_CYCLE],
            [INTRNL_ACCT]
        FROM
            [BanklineFSB].[dbo].[DDACLASS]
GO

-- %% [markdown]
-- # **CREATING NEW TABLE REG_LIMITS**

-- %%
USE [BanklineFSB]
GO
DROP TABLE IF EXISTS dbo.REG_LIMITS
GO

CREATE TABLE dbo.REG_LIMITS
(
    [JOB_NAME]              varchar(30)     NOT NULL,
    [ENTRY_DESCRIPTION]     varchar(25)     NOT NULL,
    [NUMBER]                int             NOT NULL,
    [PARAMETER]             varchar(40)     NULL,
    [DATE]                  datetime        NULL
)
GO

-- %%
USE [BanklineWNB]
GO
DROP TABLE IF EXISTS dbo.REG_LIMITS
GO

CREATE TABLE dbo.REG_LIMITS
(
    [JOB_NAME]              varchar(30)     NOT NULL,
    [ENTRY_DESCRIPTION]     varchar(25)     NOT NULL,
    [NUMBER]                int             NOT NULL,
    [PARAMETER]             varchar(40)     NULL,
    [DATE]                  datetime        NULL
)
GO

-- %% [markdown]
-- # **CREATING REG_LIMITS VIEW ON BANKLINE**

-- %%
USE [Bankline]
GO

DROP VIEW IF EXISTS [dbo].[REG_LIMITS]
GO
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE VIEW [dbo].[REG_LIMITS]
AS
            SELECT 1 AS InstitutionID,
            [JOB_NAME],
            [ENTRY_DESCRIPTION],
            [NUMBER],
            [PARAMETER],
            [DATE]
        FROM [BanklineFSB].[dbo].[REG_LIMITS]
    UNION ALL
        SELECT 2 AS InstitutionID,
            [JOB_NAME],
            [ENTRY_DESCRIPTION],
            [NUMBER],
            [PARAMETER],
            [DATE]
        FROM [BanklineWNB].[dbo].[REG_LIMITS];
GO

-- %%
USE BANKLINEWNB
GO
ALTER TABLE dbo.DDASweeps
ADD [Z_ASSOC] CHAR(10) NULL;
GO


USE BanklineFSB
GO
ALTER TABLE dbo.DDASweeps
ADD [Z_ASSOC] CHAR(10) NULL;
GO


USE [Bankline]
GO

DROP VIEW IF EXISTS [dbo].[DDASWEEPS]
GO
/****** Object:  View [dbo].[DDASWEEPS]    Script Date: 4/22/2020 1:26:48 PM ******/
SET ANSI_NULLS ON
GO

SET QUOTED_IDENTIFIER ON
GO

CREATE VIEW [dbo].[DDASWEEPS]
AS
               SELECT 1 as InstitutionID,
               [Z_ID],
               [AVAIL_BAL],
               [DEBITS],
               [CREDITS],
               [ENDING_BAL],
               [ACCT_TYP],
               [ACCT_NO],
               [MIN_BAL],
               [MAX_BAL],
               [MIN_INCREMENT],
               [AVAIL_BALS],
               [AVAIL_NET],
               [INV_APP_CODE],
               [INV_ACCOUNT],
               [LOAN_ACCOUNT],
               [AMT_TO_KEEP_AT_PARENT1],
               [AMT_TO_KEEP_AT_PARENT],
               [INV_LIMIT_MIN],
               [INV_LIMIT_MAX],
               [INV_LIMIT_INCR],
			   [Z_ASSOC]
          FROM
               [BanklineWNB].[dbo].[DDASWEEPS]
     UNION
          SELECT 2 as InstitutionID,
               [Z_ID],
               [AVAIL_BAL],
               [DEBITS],
               [CREDITS],
               [ENDING_BAL],
               [ACCT_TYP],
               [ACCT_NO],
               [MIN_BAL],
               [MAX_BAL],
               [MIN_INCREMENT],
               [AVAIL_BALS],
               [AVAIL_NET],
               [INV_APP_CODE],
               [INV_ACCOUNT],
               [LOAN_ACCOUNT],
               [AMT_TO_KEEP_AT_PARENT1],
               [AMT_TO_KEEP_AT_PARENT],
               [INV_LIMIT_MIN],
               [INV_LIMIT_MAX],
               [INV_LIMIT_INCR],
			   [Z_ASSOC]
          FROM
               [BanklineFSB].[dbo].[DDASWEEPS]
GO

-- %%
USE [BANKLINEWNB]
GO

/****** Object:  Table [dbo].[CD_DDACLASS]    Script Date: 4/22/2020 1:35:24 PM ******/
SET ANSI_NULLS ON
GO

SET QUOTED_IDENTIFIER ON
GO

CREATE TABLE [dbo].[CD_DDACLASS](
	[CLASS] [varchar](3) NULL,
	[CLASS_DESC] [varchar](45) NULL,
	[DP_MIN_OPEN] [money] NULL,
	[INT_RATE] [money] NULL,
	[INT_TYPE] [varchar](10) NULL,
	[HI_BAL] [money] NULL,
	[HI_DEPOSIT] [money] NULL,
	[YTD_MAX_DEP] [money] NULL,
	[HI_CHK_DEP] [money] NULL,
	[HI_DEP_CNT] [money] NULL,
	[HI_CHEX_CNT] [money] NULL,
	[1099_REQ] [char](1) NULL,
	[OWNER_DOB] [char](1) NULL,
	[SIG_BAL_CHG] [money] NULL,
	[FDIC_ASSMNT] [char](1) NULL,
	[STT_SVC_CHG] [int] NULL,
	[STT_PR_AVG] [char](1) NULL,
	[STT_PR_AVGC] [char](1) NULL,
	[STT_PR_MIN] [char](1) NULL,
	[DP_VAR_FLAG] [char](1) NULL,
	[ZIP_SORT] [char](1) NULL,
	[SAVINGS] [char](1) NULL,
	[MM_ACCOUNT] [char](1) NULL,
	[ANNUAL_SC] [char](1) NULL,
	[DFLT_OD_LIM] [int] NULL,
	[REVOKE_ODDY] [int] NULL,
	[REVOKE_ODS] [int] NULL,
	[STT_PRT_RT] [int] NULL,
	[TAXABLE] [int] NULL,
	[DFLT_SVC_CD] [varchar](10) NULL,
	[DFLT_FED_CT] [varchar](5) NULL,
	[DFLT_IMG_ST] [char](1) NULL,
	[DFLT_NIMGWV] [char](1) NULL,
	[ADJ_SVC_OD] [char](1) NULL,
	[AFTER_W1] [int] NULL,
	[PSTV_PAY_OK] [int] NULL,
	[DEF_MAX_FEE] [money] NULL,
	[HSA] [char](1) NULL,
	[NOW] [char](1) NULL,
	[CALLR] [varchar](3) NULL,
	[MKT_DESCRP1] [varchar](40) NULL,
	[MKT_DESCRP2] [varchar](40) NULL,
	[MKT_DESCRP3] [varchar](40) NULL,
	[IB_DISPLAY] [varchar](3) NULL,
	[IB_XFER_FRM] [varchar](3) NULL,
	[IB_XFER_TO] [varchar](3) NULL,
	[VR_DISPLAY] [varchar](3) NULL,
	[VR_XFER_FRM] [varchar](3) NULL,
	[VR_XFER_TO] [varchar](3) NULL,
	[BYPASS_RC_O] [varchar](3) NULL,
	[DEF_PC_BNKG] [varchar](3) NULL,
	[DEF_INTBLPY] [varchar](3) NULL,
	[DEF_EVNTMSG] [varchar](3) NULL,
	[DEF_ENOTICS] [varchar](3) NULL,
	[SETUP_FEE] [varchar](6) NULL,
	[CLS_CHG_FEE] [varchar](6) NULL,
	[WV_C_OD_FEE] [smallint] NULL,
	[TIERED_FEE] [money] NULL,
	[DISPLAY_PRI] [varchar](3) NULL,
	[DISPLAY_Y_N] [char](1) NULL,
	[AFTER_W1_AA] [char](3) NULL,
	[DFLT_WV_NSF] [char](3) NULL,
	[DFLT_WV_OD] [char](3) NULL,
	[DFLT_WV_COD] [char](3) NULL,
	[DFLT_PY_ALL] [char](3) NULL,
	[DFLT_WV_CBK] [char](3) NULL,
	[DFLT_CYCLE] [char](3) NULL,
	[INTRNL_ACCT] [char](3) NULL
) ON [PRIMARY]
GO

USE [BanklineFSB]
GO

/****** Object:  Table [dbo].[CD_DDACLASS]    Script Date: 4/22/2020 1:35:24 PM ******/
SET ANSI_NULLS ON
GO

SET QUOTED_IDENTIFIER ON
GO

CREATE TABLE [dbo].[CD_DDACLASS](
	[CLASS] [varchar](3) NULL,
	[CLASS_DESC] [varchar](45) NULL,
	[DP_MIN_OPEN] [money] NULL,
	[INT_RATE] [money] NULL,
	[INT_TYPE] [varchar](10) NULL,
	[HI_BAL] [money] NULL,
	[HI_DEPOSIT] [money] NULL,
	[YTD_MAX_DEP] [money] NULL,
	[HI_CHK_DEP] [money] NULL,
	[HI_DEP_CNT] [money] NULL,
	[HI_CHEX_CNT] [money] NULL,
	[1099_REQ] [char](1) NULL,
	[OWNER_DOB] [char](1) NULL,
	[SIG_BAL_CHG] [money] NULL,
	[FDIC_ASSMNT] [char](1) NULL,
	[STT_SVC_CHG] [int] NULL,
	[STT_PR_AVG] [char](1) NULL,
	[STT_PR_AVGC] [char](1) NULL,
	[STT_PR_MIN] [char](1) NULL,
	[DP_VAR_FLAG] [char](1) NULL,
	[ZIP_SORT] [char](1) NULL,
	[SAVINGS] [char](1) NULL,
	[MM_ACCOUNT] [char](1) NULL,
	[ANNUAL_SC] [char](1) NULL,
	[DFLT_OD_LIM] [int] NULL,
	[REVOKE_ODDY] [int] NULL,
	[REVOKE_ODS] [int] NULL,
	[STT_PRT_RT] [int] NULL,
	[TAXABLE] [int] NULL,
	[DFLT_SVC_CD] [varchar](10) NULL,
	[DFLT_FED_CT] [varchar](5) NULL,
	[DFLT_IMG_ST] [char](1) NULL,
	[DFLT_NIMGWV] [char](1) NULL,
	[ADJ_SVC_OD] [char](1) NULL,
	[AFTER_W1] [int] NULL,
	[PSTV_PAY_OK] [int] NULL,
	[DEF_MAX_FEE] [money] NULL,
	[HSA] [char](1) NULL,
	[NOW] [char](1) NULL,
	[CALLR] [varchar](3) NULL,
	[MKT_DESCRP1] [varchar](40) NULL,
	[MKT_DESCRP2] [varchar](40) NULL,
	[MKT_DESCRP3] [varchar](40) NULL,
	[IB_DISPLAY] [varchar](3) NULL,
	[IB_XFER_FRM] [varchar](3) NULL,
	[IB_XFER_TO] [varchar](3) NULL,
	[VR_DISPLAY] [varchar](3) NULL,
	[VR_XFER_FRM] [varchar](3) NULL,
	[VR_XFER_TO] [varchar](3) NULL,
	[BYPASS_RC_O] [varchar](3) NULL,
	[DEF_PC_BNKG] [varchar](3) NULL,
	[DEF_INTBLPY] [varchar](3) NULL,
	[DEF_EVNTMSG] [varchar](3) NULL,
	[DEF_ENOTICS] [varchar](3) NULL,
	[SETUP_FEE] [varchar](6) NULL,
	[CLS_CHG_FEE] [varchar](6) NULL,
	[WV_C_OD_FEE] [smallint] NULL,
	[TIERED_FEE] [money] NULL,
	[DISPLAY_PRI] [varchar](3) NULL,
	[DISPLAY_Y_N] [char](1) NULL,
	[AFTER_W1_AA] [char](3) NULL,
	[DFLT_WV_NSF] [char](3) NULL,
	[DFLT_WV_OD] [char](3) NULL,
	[DFLT_WV_COD] [char](3) NULL,
	[DFLT_PY_ALL] [char](3) NULL,
	[DFLT_WV_CBK] [char](3) NULL,
	[DFLT_CYCLE] [char](3) NULL,
	[INTRNL_ACCT] [char](3) NULL
) ON [PRIMARY]
GO

-- %%
USE [Bankline]
GO

/****** Object:  View [dbo].[CD_DDACLASS]    Script Date: 4/22/2020 1:38:43 PM ******/
SET ANSI_NULLS ON
GO

SET QUOTED_IDENTIFIER ON
GO

CREATE VIEW [dbo].[CD_DDACLASS]
AS
            SELECT 1 as InstitutionID,
            [class],
            [class_desc],
            --[Acct_type],
            [DP_MIN_OPEN],
            [INT_RATE],
            [INT_TYPE],
            [HI_BAL],
            [HI_DEPOSIT],
            [YTD_MAX_DEP],
            [HI_CHK_DEP],
            [HI_DEP_CNT],
            [HI_CHEX_CNT],
            [1099_REQ],
            [OWNER_DOB],
            [SIG_BAL_CHG],
            [FDIC_ASSMNT],
            [STT_SVC_CHG],
            [STT_PR_AVG],
            [STT_PR_AVGC],
            [STT_PR_MIN],
            [DP_VAR_FLAG],
            [ZIP_SORT],
            [SAVINGS],
            [MM_ACCOUNT],
            [ANNUAL_SC],
            [DFLT_OD_LIM],
            [REVOKE_ODDY],
            [REVOKE_ODS],
            [STT_PRT_RT],
            [TAXABLE],
            [DFLT_SVC_CD],
            [DFLT_FED_CT],
            [DFLT_IMG_ST],
            [DFLT_NIMGWV],
            [ADJ_SVC_OD],
            [AFTER_W1],
            [PSTV_PAY_OK],
            [DEF_MAX_FEE],
            [HSA],
            [NOW],
            [CALLR],
            [MKT_DESCRP1],
            [MKT_DESCRP2],
            [MKT_DESCRP3],
            [IB_DISPLAY],
            [IB_XFER_FRM],
            [IB_XFER_TO],
            [VR_DISPLAY],
            [VR_XFER_FRM],
            [VR_XFER_TO],
            [BYPASS_RC_O],
            [DEF_PC_BNKG],
            [DEF_INTBLPY],
            [DEF_EVNTMSG],
            [DEF_ENOTICS],
            [SETUP_FEE],
            [CLS_CHG_FEE],
            [WV_C_OD_FEE],
            [TIERED_FEE],
            [DISPLAY_PRI],
            [DISPLAY_Y_N],
            [AFTER_W1_AA],
            [DFLT_WV_NSF],
            [DFLT_WV_OD],
            [DFLT_WV_COD],
            [DFLT_PY_ALL],
            [DFLT_WV_CBK],
            [DFLT_CYCLE],
            [INTRNL_ACCT]
        FROM
            [BanklineWNB].[dbo].[CD_DDACLASS]
    UNION
        SELECT 2 as InstitutionID,
            [class],
            [class_desc],
            --[Acct_type],
            [DP_MIN_OPEN],
            [INT_RATE],
            [INT_TYPE],
            [HI_BAL],
            [HI_DEPOSIT],
            [YTD_MAX_DEP],
            [HI_CHK_DEP],
            [HI_DEP_CNT],
            [HI_CHEX_CNT],
            [1099_REQ],
            [OWNER_DOB],
            [SIG_BAL_CHG],
            [FDIC_ASSMNT],
            [STT_SVC_CHG],
            [STT_PR_AVG],
            [STT_PR_AVGC],
            [STT_PR_MIN],
            [DP_VAR_FLAG],
            [ZIP_SORT],
            [SAVINGS],
            [MM_ACCOUNT],
            [ANNUAL_SC],
            [DFLT_OD_LIM],
            [REVOKE_ODDY],
            [REVOKE_ODS],
            [STT_PRT_RT],
            [TAXABLE],
            [DFLT_SVC_CD],
            [DFLT_FED_CT],
            [DFLT_IMG_ST],
            [DFLT_NIMGWV],
            [ADJ_SVC_OD],
            [AFTER_W1],
            [PSTV_PAY_OK],
            [DEF_MAX_FEE],
            [HSA],
            [NOW],
            [CALLR],
            [MKT_DESCRP1],
            [MKT_DESCRP2],
            [MKT_DESCRP3],
            [IB_DISPLAY],
            [IB_XFER_FRM],
            [IB_XFER_TO],
            [VR_DISPLAY],
            [VR_XFER_FRM],
            [VR_XFER_TO],
            [BYPASS_RC_O],
            [DEF_PC_BNKG],
            [DEF_INTBLPY],
            [DEF_EVNTMSG],
            [DEF_ENOTICS],
            [SETUP_FEE],
            [CLS_CHG_FEE],
            [WV_C_OD_FEE],
            [TIERED_FEE],
            [DISPLAY_PRI],
            [DISPLAY_Y_N],
            [AFTER_W1_AA],
            [DFLT_WV_NSF],
            [DFLT_WV_OD],
            [DFLT_WV_COD],
            [DFLT_PY_ALL],
            [DFLT_WV_CBK],
            [DFLT_CYCLE],
            [INTRNL_ACCT]
        FROM
            [BanklineFSB].[dbo].[CD_DDACLASS]
GO
